# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test_dt = pd.read_parquet('/mnt/iusers01/fatpou01/compsci01/k09562zs/scratch/Face_data/Face/NoXI/002_2016-03-17_Paris/Expert_video/1.parquet')

# %%
len

# %%
test_dt.iloc[:,list(range(137,155))]
# Out:
#      AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  AU07_r  AU09_r  AU10_r  AU12_r  \
# 0       0.0    0.08    0.00    0.68     0.0    0.03    0.77     0.0     0.0
# 1       0.0    0.25    0.10    0.71     0.0    0.00    0.85     0.0     0.0
# 2       0.0    0.20    0.22    0.56     0.0    0.00    0.91     0.0     0.0
# 3       0.0    0.31    0.12    0.66     0.0    0.09    0.86     0.0     0.0
# 4       0.0    0.40    0.33    0.50     0.0    0.17    0.80     0.0     0.0
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 746     0.0    0.40    0.00    1.42     0.0    0.00    0.59     0.0     0.0
# 747     0.0    0.35    0.00    1.81     0.0    0.02    0.54     0.0     0.0
# 748     0.0    0.58    0.00    1.79     0.0    0.00    0.51     0.0     0.0
# 749     0.0    0.47    0.00    1.43     0.0    0.00    0.61     0.0     0.0
# 750     0.0    0.44    0.00    1.63     0.0    0.00    0.77     0.0     0.0
#
# ...

# %%
test_dt.describe()
# Out:
#             frame         x_0         x_1         x_2         x_3         x_4  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean   376.000000   51.874699   51.392010   52.204395   54.356327   59.524235
# std    216.938522    4.151703    4.135189    4.163506    4.179538    4.037737
# min      1.000000   37.000000   37.299999   38.000000   40.000000   45.700001
# 25%    188.500000   50.299999   49.700001   50.400002   52.400002   57.500000
# 50%    376.000000   52.200001   51.599998   52.299999   54.400002   59.500000
# 75%    563.500000   54.200001   53.799999   54.700001   56.799999   61.799999
# max    751.000000   62.599998   62.400002   63.700001   66.500000   72.000000
#
#               x_5         x_6         x_7         x_8  ...      AU26_r  \
# count  751.000000  751.000000  751.000000  751.000000  ...  751.000000
# mean    69.392677   81.860985   97.638756  114.821709  ...    0.029321
# ...

# %%
len(list(range(137, 154))  )
# Out:
# 17
